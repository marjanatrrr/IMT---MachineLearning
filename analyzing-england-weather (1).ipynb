# %% [markdown]
# # 🌦️ **England Weather Dataset Overview** 🌦️
#
# This dataset provides **comprehensive hourly weather data** for England, covering a decade from **2006 to 2016**. It includes key meteorological parameters, making it ideal for **time-series analysis** and **weather predictions**.
#
# ---
#
# ### <span style="color: #4CAF50;">📋 **Dataset Columns**:</span>
# | **Column Name**          | **Description**                                                      |
# |--------------------------|----------------------------------------------------------------------|
# | <span style="color: #5a9bd5;">`Formatted Date`</span>     | Precise timestamp for the recorded data, including timezone.        |
# | <span style="color: #5a9bd5;">`Summary`</span>            | A brief description of the weather condition (e.g., Partly Cloudy). |
# | <span style="color: #5a9bd5;">`Precip Type`</span>        | Type of precipitation observed (e.g., rain).                       |
# | <span style="color: #5a9bd5;">`Temperature (C)`</span>    | The recorded temperature in Celsius.                               |
# | <span style="color: #5a9bd5;">`Wind Speed (km/h)`</span>  | Speed of the wind in kilometers per hour.                          |
# | <span style="color: #5a9bd5;">`Pressure (millibars)`</span>| Atmospheric pressure in millibars.                                 |
# | <span style="color: #5a9bd5;">`Humidity`</span>           | Relative humidity (on a scale of 0 to 1).                         |
#
# ---
#
# ### <span style="color: #FF5722;">🔍 **Key Highlights**:</span>
# - **⏳ Time Range**: Covers weather data from **April 2006 to September 2016**.
# - **🔢 Granularity**: Hourly records provide fine-grained insights into weather patterns.
# - **📊 Size**: Includes **96,453 rows** of weather observations.
# - **🎯 Utility**: Suitable for analyzing **seasonal trends**, **wind patterns**, or **precipitation types**.
#
# ---
#
# ### <span style="color: #2196F3;">💡 **Exploration Ideas**:</span>
# - **🌡️ Compare temperature trends** over the years to identify **seasonal variations**.
# - **💧 Examine the relationship** between **humidity** and **precipitation types**.
# - **🌬️ Analyze pressure and wind speed correlations** for **storm predictions**.
#
# ---
#
# 🎯 **This dataset** is a **perfect tool** for diving deep into **England's atmospheric trends**!
# *England's atmospheric trends**!

# %%
# import requierment libarary
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
data= pd.read_csv("/kaggle/input/england/EnglandWeather.csv")
dff=pd.DataFrame(data)
dff
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Wind Speed (km/h)  Pressure (millibars)  Humidity
# 0             9.472222            14.1197               1015.13      0.89
# ...

# %%
dff.head(5)
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Wind Speed (km/h)  Pressure (millibars)  Humidity
# 0            14.1197               1015.13      0.89
# 1            14.2646               1015.63      0.86
# 2             3.9284               1015.94      0.89
# 3            14.1036               1016.41      0.83
# 4            11.0446               1016.51      0.83

# %%
dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Formatted Date        96453 non-null  object
#  1   Summary               96453 non-null  object
#  2   Precip Type           95936 non-null  object
#  3   Temperature (C)       96453 non-null  float64
#  4   Wind Speed (km/h)     96453 non-null  float64
#  5   Pressure (millibars)  96453 non-null  float64
#  6   Humidity              96453 non-null  float64
# dtypes: float64(4), object(3)
# memory usage: 5.2+ MB

# %%
dff.describe()
# Out:
#        Temperature (C)  Wind Speed (km/h)  Pressure (millibars)      Humidity
# count     96453.000000       96453.000000          96453.000000  96453.000000
# mean         11.932678          10.810640           1003.235956      0.734899
# std           9.551546           6.913571            116.969906      0.195473
# min         -21.822222           0.000000              0.000000      0.000000
# 25%           4.688889           5.828200           1011.900000      0.600000
# 50%          12.000000           9.965900           1016.450000      0.780000
# 75%          18.838889          14.135800           1021.090000      0.890000
# max          39.905556          63.852600           1046.380000      1.000000

# %%
df_obj = dff.select_dtypes(['object'])
df_obj.describe()
# Out:
#                        Formatted Date        Summary Precip Type
# count                           96453          96453       95936
# unique                          96429             27           2
# top     2010-08-02 00:00:00.000 +0200  Partly Cloudy        rain
# freq                                2          31733       85224

# %%
# Splitting date and time from "Formatted Date" column and dropping the original column
dff[['date', 'time']] = dff['Formatted Date'].str.split(' ', n=1, expand=True)
dff1 = dff.drop(columns=['Formatted Date'])
dff1
# Out:
#              Summary Precip Type  Temperature (C)  Wind Speed (km/h)  \
# 0      Partly Cloudy        rain         9.472222            14.1197
# 1      Partly Cloudy        rain         9.355556            14.2646
# 2      Mostly Cloudy        rain         9.377778             3.9284
# 3      Partly Cloudy        rain         8.288889            14.1036
# 4      Mostly Cloudy        rain         8.755556            11.0446
# ...              ...         ...              ...                ...
# 96448  Partly Cloudy        rain        26.016667            10.9963
# 96449  Partly Cloudy        rain        24.583333            10.0947
# 96450  Partly Cloudy        rain        22.038889             8.9838
# 96451  Partly Cloudy        rain        21.522222            10.5294
# 96452  Partly Cloudy        rain        20.438889             5.8765
#
#        Pressure (millibars)  Humidity        date                time
# ...

# %%
print(dff1['date'].unique())
# Out:
# ['2006-04-01' '2006-04-10' '2006-04-11' ... '2016-09-07' '2016-09-08'
#  '2016-09-09']

# %%
dff1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Summary               96453 non-null  object
#  1   Precip Type           95936 non-null  object
#  2   Temperature (C)       96453 non-null  float64
#  3   Wind Speed (km/h)     96453 non-null  float64
#  4   Pressure (millibars)  96453 non-null  float64
#  5   Humidity              96453 non-null  float64
#  6   date                  96453 non-null  object
#  7   time                  96453 non-null  object
# dtypes: float64(4), object(4)
# memory usage: 5.9+ MB

# %%
# Detect duplicate data in your DataFrame 'dff1'
duplicate_data = dff1[dff1.duplicated()]

# Print the number of duplicated data
print(f'Number of duplicated data: {len(duplicate_data)}')

# Print the duplicated rows
if len(duplicate_data) > 0:
    print("Duplicated data rows:")
    print(duplicate_data)
else:
    print("No duplicated data found.")
# Out:
# Number of duplicated data: 24
# Duplicated data rows:
#              Summary Precip Type  Temperature (C)  Wind Speed (km/h)  \
# 36072          Clear        rain        18.800000             6.2790
# 36073          Clear        rain        18.222222             6.2790
# 36074          Clear        rain        18.072222            11.2700
# 36075          Clear        rain        16.622222             6.4400
# 36076          Clear        rain        16.094444             3.0751
# 36077          Clear        rain        15.955556             3.8801
# 36078          Clear        rain        17.088889             6.4400
# 36079          Clear        rain        20.822222             3.2200
# 36080          Clear        rain        23.405556             1.8837
# 36081          Clear        rain        26.050000             1.5939
# 36082          Clear        rain        27.688889             0.2254
# 36083          Clear        rain        28.561111             3.2039
# ...

# %%
# Create a copy of the DataFrame 'dff1'
dff2 = dff1.copy()

# Drop duplicates from the copied DataFrame
dff2 = dff1.drop_duplicates()

# Display the DataFrame after removing duplicates
dff2
# Out:
#              Summary Precip Type  Temperature (C)  Wind Speed (km/h)  \
# 0      Partly Cloudy        rain         9.472222            14.1197
# 1      Partly Cloudy        rain         9.355556            14.2646
# 2      Mostly Cloudy        rain         9.377778             3.9284
# 3      Partly Cloudy        rain         8.288889            14.1036
# 4      Mostly Cloudy        rain         8.755556            11.0446
# ...              ...         ...              ...                ...
# 96448  Partly Cloudy        rain        26.016667            10.9963
# 96449  Partly Cloudy        rain        24.583333            10.0947
# 96450  Partly Cloudy        rain        22.038889             8.9838
# 96451  Partly Cloudy        rain        21.522222            10.5294
# 96452  Partly Cloudy        rain        20.438889             5.8765
#
#        Pressure (millibars)  Humidity        date                time
# ...

# %% [markdown]
# ## <span style="color: #FF9800;">⚠️ **Missing Value**</span>

# %%
dff2.isna().sum()
# Out:
# Summary                   0
# Precip Type             517
# Temperature (C)           0
# Wind Speed (km/h)         0
# Pressure (millibars)      0
# Humidity                  0
# date                      0
# time                      0
# dtype: int64

# %%
miss_val = dff2[dff2['Precip Type'].isna()]
miss_val
# Out:
#              Summary Precip Type  Temperature (C)  Wind Speed (km/h)  \
# 52672  Mostly Cloudy         NaN        19.016667            14.8764
# 52674  Mostly Cloudy         NaN        17.850000            13.7977
# 52675  Mostly Cloudy         NaN        16.322222            10.8192
# 52677  Mostly Cloudy         NaN        12.566667             9.0160
# 52678  Mostly Cloudy         NaN        12.927778            17.6295
# ...              ...         ...              ...                ...
# 95584  Mostly Cloudy         NaN         8.322222             8.0339
# 95585  Mostly Cloudy         NaN         7.627778             8.2271
# 95586  Mostly Cloudy         NaN         7.111111             8.5008
# 95587  Partly Cloudy         NaN         6.672222             8.6457
# 95588  Mostly Cloudy         NaN         6.322222             8.4686
#
#        Pressure (millibars)  Humidity        date                time
# ...

# %%
# Counting the types of precipitation in data where temperature is above zero
pre_type_counts = dff2[dff2['Temperature (C)'] >= 0]['Precip Type'].value_counts()
print(pre_type_counts)

# Since the precipitation type for data with temperature above zero is mainly rain, 
# we fill missing values with 'rain'
dff3 = dff2.copy()
dff3.fillna('rain', inplace=True)

# Displaying the final result
dff3
# Out:
# Precip Type
# rain    85200
# snow      325
# Name: count, dtype: int64
#              Summary Precip Type  Temperature (C)  Wind Speed (km/h)  \
# 0      Partly Cloudy        rain         9.472222            14.1197
# 1      Partly Cloudy        rain         9.355556            14.2646
# 2      Mostly Cloudy        rain         9.377778             3.9284
# 3      Partly Cloudy        rain         8.288889            14.1036
# 4      Mostly Cloudy        rain         8.755556            11.0446
# ...              ...         ...              ...                ...
# 96448  Partly Cloudy        rain        26.016667            10.9963
# 96449  Partly Cloudy        rain        24.583333            10.0947
# 96450  Partly Cloudy        rain        22.038889             8.9838
# 96451  Partly Cloudy        rain        21.522222            10.5294
# 96452  Partly Cloudy        rain        20.438889             5.8765
#
# ...

# %%
# verifing
dff3.isna().sum()
# Out:
# Summary                 0
# Precip Type             0
# Temperature (C)         0
# Wind Speed (km/h)       0
# Pressure (millibars)    0
# Humidity                0
# date                    0
# time                    0
# dtype: int64

# %%
# Checking for zero pressure in the dataframe
zero_pressure_count = (dff3['Pressure (millibars)'] == 0).sum()

if zero_pressure_count > 0:
    print(f'Number of records with zero pressure: {zero_pressure_count}')
else:
    print('No records with zero pressure found.')
# Out:
# Number of records with zero pressure: 1288

# %%
# Removing records where pressure is equal to zero
dff3 = dff3[dff3['Pressure (millibars)'] != 0]

# Displaying the number of remaining records
print(f'Number of remaining records: {len(dff3)}')
# Out:
# Number of remaining records: 95141

# %% [markdown]
# <span style="color: #2A9DF4;">Records with zero pressure are meaningless, so we remove them to ensure the integrity of our dataset.</span>

# %%
dff3
# Out:
#              Summary Precip Type  Temperature (C)  Wind Speed (km/h)  \
# 0      Partly Cloudy        rain         9.472222            14.1197
# 1      Partly Cloudy        rain         9.355556            14.2646
# 2      Mostly Cloudy        rain         9.377778             3.9284
# 3      Partly Cloudy        rain         8.288889            14.1036
# 4      Mostly Cloudy        rain         8.755556            11.0446
# ...              ...         ...              ...                ...
# 96448  Partly Cloudy        rain        26.016667            10.9963
# 96449  Partly Cloudy        rain        24.583333            10.0947
# 96450  Partly Cloudy        rain        22.038889             8.9838
# 96451  Partly Cloudy        rain        21.522222            10.5294
# 96452  Partly Cloudy        rain        20.438889             5.8765
#
#        Pressure (millibars)  Humidity        date                time
# ...

# %%
# 1. Convert humidity to percentage for better analyze
dff3.loc[:, 'Humidity'] = dff3['Humidity'] * 100
dff3
# Out:
#              Summary Precip Type  Temperature (C)  Wind Speed (km/h)  \
# 0      Partly Cloudy        rain         9.472222            14.1197
# 1      Partly Cloudy        rain         9.355556            14.2646
# 2      Mostly Cloudy        rain         9.377778             3.9284
# 3      Partly Cloudy        rain         8.288889            14.1036
# 4      Mostly Cloudy        rain         8.755556            11.0446
# ...              ...         ...              ...                ...
# 96448  Partly Cloudy        rain        26.016667            10.9963
# 96449  Partly Cloudy        rain        24.583333            10.0947
# 96450  Partly Cloudy        rain        22.038889             8.9838
# 96451  Partly Cloudy        rain        21.522222            10.5294
# 96452  Partly Cloudy        rain        20.438889             5.8765
#
#        Pressure (millibars)  Humidity        date                time
# ...

# %%
# Create a new 'time' column to keep only hours and minutes
dff3.loc[:, 'time'] = dff3['time'].str.split(':').str[:2].str.join(':')  # Remove seconds

# Display the updated dataframe
print(dff3[['date', 'time']])  # Show only the 'date' and 'time' columns
# Out:
#              date   time
# 0      2006-04-01  00:00
# 1      2006-04-01  01:00
# 2      2006-04-01  02:00
# 3      2006-04-01  03:00
# 4      2006-04-01  04:00
# ...           ...    ...
# 96448  2016-09-09  19:00
# 96449  2016-09-09  20:00
# 96450  2016-09-09  21:00
# 96451  2016-09-09  22:00
# 96452  2016-09-09  23:00
#
# [95141 rows x 2 columns]

# %%
dff3
# Out:
#              Summary Precip Type  Temperature (C)  Wind Speed (km/h)  \
# 0      Partly Cloudy        rain         9.472222            14.1197
# 1      Partly Cloudy        rain         9.355556            14.2646
# 2      Mostly Cloudy        rain         9.377778             3.9284
# 3      Partly Cloudy        rain         8.288889            14.1036
# 4      Mostly Cloudy        rain         8.755556            11.0446
# ...              ...         ...              ...                ...
# 96448  Partly Cloudy        rain        26.016667            10.9963
# 96449  Partly Cloudy        rain        24.583333            10.0947
# 96450  Partly Cloudy        rain        22.038889             8.9838
# 96451  Partly Cloudy        rain        21.522222            10.5294
# 96452  Partly Cloudy        rain        20.438889             5.8765
#
#        Pressure (millibars)  Humidity        date   time
# 0                   1015.13      89.0  2006-04-01  00:00
# ...

# %% [markdown]
# <h2 style="color: #4caf50;">🔍 EDA: Exploratory Data Analysis</h2>

# %%
correlation = dff3[['Temperature (C)', 'Wind Speed (km/h)', 'Pressure (millibars)', 'Humidity']].corr()

plt.figure(figsize=(5, 5))
sns.heatmap(correlation, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5, linecolor='black', cbar_kws={"shrink": .8})
plt.title('Correlation Heatmap', fontsize=20)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 🔍 **Correlation Analysis:**
#
# - 🌡️ **Temperature and Humidity:**
#   A **strong negative correlation** of **-0.63**, indicating that as **temperature** increases, **humidity** tends to decrease.
#
# - 🌡️ **Temperature and Pressure:**
#   A **moderate negative correlation** of **-0.31**, suggesting that **temperature** and **pressure** are inversely related to some extent.
#
# - 🌬️ **Wind Speed:**
#   Shows a **weak correlation** with the other variables, indicating minimal linear relationships.

# %%
plt.figure(figsize=(7, 5))
sns.scatterplot(data=dff3, x='Humidity', y='Temperature (C)', hue='Precip Type', style='Precip Type', palette='Set1', s=100, alpha=0.7)
plt.title('Temperature vs Humidity', fontsize=16)
plt.xlabel('Humidity (%)', fontsize=14)
plt.ylabel('Temperature (°C)', fontsize=14)
plt.legend(title='Precipitation Type', fontsize=12)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# 🌡️ **Temperature Differences for Rain and Snow**:
# - ❄️ **Snow**: Typically occurs at lower temperatures (below **0°C**).
# - 🌧️ **Rain**: Observed at temperatures above **0°C**.
#
# 💧 **Humidity and Precipitation Type**:
# - ❄️ **Snow**: Mostly occurs in humidity levels ranging from **40% to 100%**.
# - 🌧️ **Rain**: Found across a broader range of humidity levels but is more common at **humidity above 60%**.
#
# 📊 **Overall Relationship Between Temperature and Humidity**:
# - As **humidity increases**, there is a relative **decrease in temperature**.
# - The scatterplot indicates that **precipitation type** significantly influences the distribution of temperature and humidity.

# %%
plt.figure(figsize=(7, 5))
sns.histplot(dff3['Temperature (C)'], kde=True, bins=30, color='green', alpha=0.6)
plt.title('Distribution of Temperature', fontsize=15)
plt.xlabel('Temperature (°C)', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Convert 'date' column to datetime format if not already
dff3['date'] = pd.to_datetime(dff3['date'])

# Sort the dataframe by 'date' to ensure correct plotting order
dff3 = dff3.sort_values(by='date')

# Identify numeric columns excluding 'date'
numeric_columns = dff3.select_dtypes(include='number').columns

palette = sns.color_palette("coolwarm", len(numeric_columns))

# Plotting for each numeric column
for i, column in enumerate(numeric_columns):
    plt.figure(figsize=(10, 5))  # Adjusted smaller figure size
    sns.lineplot(data=dff3, x='date', y=column, marker='o', color=palette[i])
    plt.title(f'{column} Over Time', fontsize=16, fontweight='bold')
    plt.xlabel('Date', fontsize=12)
    plt.ylabel(column, fontsize=12)
    plt.xticks(rotation=45, fontsize=10)
    plt.yticks(fontsize=10)
    plt.grid(True, linestyle='--', linewidth=0.5, alpha=0.7)
    plt.tight_layout()
    plt.show()
# Out:
# /tmp/ipykernel_17/135157213.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dff3['date'] = pd.to_datetime(dff3['date'])

# %% [markdown]
# ## 📊 **Analysis of the Plots**
#
# ---
#
# ### 📊 **First Plot: Temperature Variations Over Time**
#
# 📝 **Main Observation**:
# This chart shows the **temperature variations** across several years, from **2006 to 2016**. The data points clearly represent the fluctuations in temperature over this time period.
#
# ### 🌦️ **Seasonal Patterns**:
# There appears to be a **periodic or seasonal pattern** in the temperature, with recurring peaks and drops within each year. This is likely due to seasonal changes, such as **summer** and **winter** cycles.
#
# ### 🔶 **Scatter Plot**:
# The data points are represented using a **bold orange color** and connected with continuous lines, which effectively highlight the fluctuations over time.
#
# ### 📈 **Averaged Trend Lines**:
# The chart includes a **trend line or moving average**, shown with thinner lines, indicating slight deviations from the overall trend.
#
# ### 🌡️ **Temperature Range**:
# Overall, the temperature ranges from around **5°C to over 30°C**, indicating significant variations in climate conditions throughout the years.
#
# ### ✅ **Conclusion**:
# This chart successfully visualizes the **temperature trends** over multiple years, with a recurring pattern seen in each year. These fluctuations likely reflect **seasonal changes**.
#
# ---
#
# ### 📊 **Second Plot: Wind Speed (km/h) Over Time**
#
# 📝 **Main Observation**:
# This plot shows the variation in **wind speed** over time. The data points are represented in a **light blue** scatter plot.
#
# ### 🔍 **Patterns**:
# - Wind speed fluctuates between about **5 to 20 km/h**, with occasional spikes reaching up to **40 km/h**.
# - The changes in wind speed appear **irregular**, possibly influenced by seasonal or specific weather conditions.
#
# ### 🔎 **Analysis**:
# The data doesn’t show a clear seasonal or cyclical trend, but the **irregular fluctuations** might be due to varying weather systems.
#
# ---
#
# ### 📊 **Third Plot: Pressure (millibars) Over Time**
#
# 📝 **Main Observation**:
# This plot shows the variation in **atmospheric pressure**, fluctuating between **980 and 1020 millibars** over the same time period as the wind speed data.
#
# ### 🔍 **Patterns**:
# - Pressure changes appear to follow a **more regular and cyclic pattern**, likely due to seasonal or specific atmospheric conditions.
# - High and low pressure points indicate different **weather systems**, such as **high pressure** (stable weather) and **low pressure** (unstable weather).
#
# ### 🔎 **Analysis**:
# This plot suggests a more predictable pattern in pressure changes, likely tied to **seasonal or cyclical weather patterns**. It could be useful for **forecasting weather conditions**.
#
# ---
# terns**. It could be useful for **forecasting weather conditions**.
# terns**. It could be useful for **forecasting weather conditions**.
#  It could be useful for **forecasting weather conditions**.
# asting weather conditions**.

# %%
# !pip install calmap

# %%
import calmap
dff3.set_index('date', inplace=True)
events = dff3['Temperature (C)'].resample('D').mean()

plt.figure(figsize=(12, 8))
calmap.yearplot(events, cmap='coolwarm', fillcolor='white', linewidth=0.5)
plt.title('Calendar Heatmap of Daily Average Temperature', fontsize=20)
plt.show()

# %% [markdown]
# ### 🌍 **Overview of the Calendar Heatmap**
#
# This heatmap visualizes **daily average temperatures** throughout the year, using a calendar-style layout.
#
# - **Rows** represent the days of the week (**Mon-Sun**).
# - **Columns** correspond to the months of the year.
# - Each cell represents a specific day, with colors indicating the temperature:
#
# 🎨 **Color Key:**
# - **🔵 Blue Shades:** Represent colder days (low temperatures).
# - **🔴 Red Shades:** Indicate warmer days (high temperatures).
#
# ---
#
# ### 🌸 **Seasonal Patterns**
#
# - **❄️ Winter (Jan, Feb, Dec):** Dominated by blue, showcasing the coldest days.
# - **☀️ Summer (Jun, Jul, Aug):** Red cells highlight the hottest days, with **July** standing out as the warmest.
# - **🌱 Spring (Mar-May) & 🍂 Autumn (Sep-Nov):** A mix of blue, orange, and neutral shades reflects moderate temperatures during these transitional seasons.
#
# ---
#
# ### 🔍 **Key Observations**
#
# #### 📅 **Weekly Trends:**
# - No specific pattern is tied to weekdays; temperature changes are driven by **seasons**, not days.
#
# #### ❗ **Outliers:**
# - **📆 October:** Some warmer-than-expected days suggest unusual weather events.
# - **📆 April:** A few colder days hint at late-season cold spells.
#
# ---
#
# ### 🔧 **Applications of the Analysis**
#
# - **⚡ Energy Planning:** Helps forecast **heating needs in winter** and **cooling demand in summer**.
# - **🌾 Agriculture:** Guides **planting and harvesting schedules** based on temperature trends.
# - **🧳 Tourism:** Identifies **ideal seasons** for specific activities, such as summer vacations or winter sports.
#
# ---
#
# ### ✅ **Conclusion**
#
# This heatmap provides a **clear visual summary** of temperature variations across the year, highlighting **seasonal patterns** and **anomalies** that can inform:
# - **Energy management**
# - **Agriculture planning**
# - **Climate-related decisions**

# %%
palette = ['#50B8A1', '#FF6F61']
columns = ['Temperature (C)', 'Wind Speed (km/h)', 'Pressure (millibars)', 'Humidity']

# Set the number of rows and columns for the subplots
rows = (len(columns) + 1) // 2  # Number of rows
fig, axes = plt.subplots(rows, 2, figsize=(12, rows * 4))  # Width=12, height proportional to rows

# Flatten the axes array for easier iteration
axes = axes.flatten()

# Plot each column as a violin plot
for i, col in enumerate(columns):
    sns.violinplot(ax=axes[i], data=dff3, x='Precip Type', y=col, palette=palette, inner='quartile')
    axes[i].set_title(f'Violin Plot of {col} by Precipitation Type', fontsize=14)
    axes[i].set_xlabel('Precipitation Type', fontsize=12)
    axes[i].set_ylabel(col, fontsize=12)

# Remove extra axes if the number of columns is odd
for j in range(len(columns), len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 🔍 **Improved Analysis**
#
# The image showcases **four violin plots** comparing weather variables (temperature, wind speed, pressure, and humidity) based on **precipitation type** (**rain** and **snow**). Here's a detailed breakdown of the insights:
#
# ---
#
# ### 🌡️ **Temperature:**
# - **Rain:**
#   - Temperatures are generally **higher** with a **broader distribution**, indicating **warmer conditions**.
# - **Snow:**
#   - Temperatures are mostly **below zero**, with a **narrower distribution**, reflecting **cold weather**.
#
# ---
#
# ### 🌬️ **Wind Speed:**
# - **Rain:**
#   - Wind speed shows a **broader distribution** at **lower values**.
# - **Snow:**
#   - Wind speed is more **concentrated** within a **specific range**.
#
# ---
#
# ### 📉 **Pressure:**
# - **Rain:**
#   - Atmospheric pressure is **higher** with a **wider distribution**.
# - **Snow:**
#   - Pressure tends to be **lower**, with a **narrower range**, suggesting **stable snowy conditions**.
#
# ---
#
# ### 💧 **Humidity:**
# - **Rain:**
#   - Humidity levels are **high** but **widely distributed**.
# - **Snow:**
#   - Humidity values are **closer to the upper range**, showing **concentration** during snow events.
#
# ---
#
# ### ✅ **Conclusion:**
# These violin plots effectively highlight the **distinct weather patterns** for **rain** and **snow**, providing valuable insights into temperature, wind speed, pressure, and humidity variations under different precipitation conditions.

# %%
plt.figure(figsize=(7, 4))
sns.boxplot(data=dff3, x='Precip Type', y='Temperature (C)', palette='Set2')
plt.title('Box Plot of Temperature by Precipitation Type', fontsize=20)
plt.xlabel('Precipitation Type', fontsize=14)
plt.ylabel('Temperature (°C)', fontsize=14)
plt.tight_layout()
plt.show()

# %%
precip_counts = dff3['Precip Type'].value_counts()
plt.figure(figsize=(4, 4))
plt.pie(precip_counts, labels=precip_counts.index, autopct='%1.1f%%', startangle=90, colors=['orange', 'lightcoral'])
plt.title('Distribution of Precipitation Types', fontsize=20)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.kdeplot(data=dff3, x='Temperature (C)', y='Pressure (millibars)', cmap='plasma', fill=True)
plt.title('Contour Plot of Temperature and Pressure', fontsize=20)
plt.xlabel('Temperature (°C)', fontsize=14)
plt.ylabel('Pressure (millibars)', fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 🔍 **Analysis of the Plot:**
#
# #### 📊 **Data Density:**
# - **Yellow areas** indicate **higher data density**, meaning more data points are clustered within these ranges.
# - **Light to dark purple areas** show **lower density**, indicating fewer data points.
#
# ---
#
# #### 📈 **Overall Pattern:**
# - The plot shows that the **pressure** generally stays within the range of **1000 to 1020 millibars**.
# - The **temperature** typically ranges between **0 to 30°C**.
#
# ---
#
# #### 🟠 **Data Shape:**
# - The overall shape of the plot is **elliptical**, indicating a **concentration of data** in a specific area.
# - The data density gradually decreases from the center to the edges.
#
# ---
#
# #### 🔄 **Variable Relationship:**
# - There is no clear **linear relationship** between **temperature** and **pressure**, but the data is more concentrated in specific regions of the plot.
#
# ---
#
# ### 💡 **Conclusion:**
# This type of plot is useful for identifying **patterns** and **data density distribution** across two variables. The higher concentration of data within a specific range can aid in analyzing particular environmental conditions (such as atmospheric conditions).

# %%
sns.pairplot(dff3[['Temperature (C)', 'Wind Speed (km/h)', 'Pressure (millibars)', 'Humidity']], diag_kind='kde', palette='husl')
plt.suptitle('Pair Plot of Weather Features', y=1.02, fontsize=20)
plt.tight_layout()
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:1507: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:1507: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:1507: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:1507: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:1609: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# ...

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Plot with transparency, smaller points, and color bar
scatter = ax.scatter(dff3['Temperature (C)'], dff3['Wind Speed (km/h)'], dff3['Pressure (millibars)'], c=dff3['Humidity'], cmap='viridis', s=20, alpha=0.6)

# Color bar for Humidity
cbar = fig.colorbar(scatter, ax=ax, shrink=0.5, aspect=5)
cbar.set_label('Humidity', fontsize=12)

# Adjusting axis labels and title
ax.set_xlabel('Temperature (°C)', fontsize=14, labelpad=10)
ax.set_ylabel('Wind Speed (km/h)', fontsize=14, labelpad=10)
ax.set_zlabel('Pressure (millibars)', fontsize=14, labelpad=10)
plt.title('3D Scatter Plot of Temperature, Wind Speed, and Pressure', fontsize=16, pad=20)

# Adjusting the view
ax.view_init(elev=30, azim=60)

plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.scatter(dff3['Temperature (C)'], dff3['Wind Speed (km/h)'], s=dff3['Pressure (millibars)']*0.5, c=dff3['Humidity'], cmap='coolwarm', alpha=0.6, edgecolors='w', linewidth=2)
plt.title('Bubble Plot of Temperature, Wind Speed and Pressure', fontsize=20)
plt.xlabel('Temperature (°C)', fontsize=14)
plt.ylabel('Wind Speed (km/h)', fontsize=14)
plt.colorbar(label='Humidity (%)')
plt.tight_layout()
plt.show()

# %%
print(dff3.columns)
# Out:
# Index(['Summary', 'Precip Type', 'Temperature (C)', 'Wind Speed (km/h)',
#        'Pressure (millibars)', 'Humidity', 'time'],
#       dtype='object')

# %%
# Convert 'time' column to datetime type
dff3['time'] = pd.to_datetime(dff3['time'])

# Extract hour from 'time' column
dff3['hour'] = dff3['time'].dt.hour

# Plot for each numerical column
for column in ['Temperature (C)', 'Wind Speed (km/h)', 'Pressure (millibars)', 'Humidity']:
    plt.figure(figsize=(10, 5))
    sns.lineplot(data=dff3, x='hour', y=column, marker='o', color='green')  # Line plot with green color
    plt.title(f'{column} by Hour', fontsize=16)  # Title of the plot
    plt.xlabel('Hour of Day', fontsize=12)  # X-axis label
    plt.ylabel(column, fontsize=12)  # Y-axis label
    plt.xticks(ticks=range(0, 24), labels=[f'{i}:00' for i in range(24)], rotation=45, fontsize=10)  # X-axis ticks
    plt.yticks(fontsize=10)  # Y-axis ticks
    plt.grid(True, linestyle='--', linewidth=0.5, alpha=0.7)  # Gridlines
    plt.tight_layout()  # Adjust layout for better spacing
    plt.show()  # Display plot
# Out:
# /tmp/ipykernel_17/2913210737.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   dff3['time'] = pd.to_datetime(dff3['time'])

# %% [markdown]
# ---
#
# ## ✍️ **Author**: Marjan Atashkar
#
# If you liked this notebook, feel free to give it a thumbs-up! 👍
#
# ---
